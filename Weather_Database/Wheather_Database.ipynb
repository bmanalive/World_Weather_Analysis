# %%
# Import the random module.
import random

# Import the NumPy module.
import numpy as np

# Import the Pandas module.
import pandas as pd

# Import the matplotlib.pyplot module.
import matplotlib.pyplot as plt

# Import citypy
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
cities
# Out:
# ['miranda de ebro',
#  'rikitea',
#  'vaini',
#  'barroquinha',
#  'saint-philippe',
#  'jamestown',
#  'kapaa',
#  'norman wells',
#  'ribeira grande',
#  'faanui',
#  'saint anthony',
#  'albany',
#  'ksenyevka',
#  'ushuaia',
#  'mataura',
#  'tsihombe',
#  'barentsburg',
#  'maralal',
#  'kavaratti',
#  'qiyang',
#  'ulladulla',
#  'oros',
#  'puerto ayora',
#  'denpasar',
#  'port alfred',
#  'tautira',
#  'hithadhoo',
#  'saskylakh',
#  'cape town',
#  'chuy',
#  'mar del plata',
#  'adrar',
#  'manzhouli',
#  'bluff',
#  'belushya guba',
#  'mahebourg',
#  'taolanaro',
#  'pisco',
#  'port elizabeth',
#  'sibolga',
#  'torbay',
#  'korla',
#  'itumba',
#  'wanning',
#  'cherskiy',
#  'dunedin',
#  'tavda',
#  'cabedelo',
#  'sentyabrskiy',
#  'neuquen',
#  'hilo',
#  'samusu',
#  'hami',
#  'bengkulu',
#  'sioux lookout',
#  'west bend',
#  'kruisfontein',
#  'usvyaty',
#  'victoria',
#  'marsh harbour',
#  'terbuny',
#  'yellowknife',
#  'whitehorse',
#  'atuona',
#  'chiang khong',
#  'baghdad',
#  'saleaula',
#  'hermanus',
#  'mount gambier',
#  'rawson',
#  'kodiak',
#  'barrow',
#  'constitucion',
#  'kavieng',
#  'sylacauga',
#  'bambous virieux',
#  'hobart',
#  'karratha',
#  'kahului',
#  'povenets',
#  'susangerd',
#  'suhbaatar',
#  'punta arenas',
#  'cabo san lucas',
#  'atar',
#  'lebu',
#  'inhambane',
#  'lac du bonnet',
#  'fernie',
#  'taksimo',
#  'busselton',
#  'belaya gora',
#  'priladozhskiy',
#  'yabrud',
#  'mys shmidta',
#  'barra patuca',
#  'ponta do sol',
#  'marawi',
#  'louisbourg',
#  'san cristobal',
#  'itambe',
#  'grootfontein',
#  'butaritari',
#  'thunder bay',
#  'sabang',
#  'longyearbyen',
#  'bredasdorp',
#  'khorramshahr',
#  'pangnirtung',
#  'yumbe',
#  'bay city',
#  'iqaluit',
#  'flinders',
#  'khash',
#  'san policarpo',
#  'ingham',
#  'durazno',
#  'thompson',
#  'xining',
#  'georgetown',
#  'arraial do cabo',
#  'tambovka',
#  'port lincoln',
#  'hihifo',
#  'goderich',
#  'oranjemund',
#  'carutapera',
#  'tuktoyaktuk',
#  'saint george',
#  'songkhla',
#  'sinnamary',
#  'east london',
#  'surgut',
#  'deputatskiy',
#  'nizhniy kuranakh',
#  'veraval',
#  'nakhon phanom',
#  'jilib',
#  'illoqqortoormiut',
#  'henties bay',
#  'hukuntsi',
#  'castro',
#  'klaksvik',
#  'lokoja',
#  'tiksi',
#  'inirida',
#  'suffolk',
#  'quatre cocos',
#  'correntina',
#  'mount isa',
#  'dikson',
#  'champerico',
#  'singapore',
#  'tessalit',
#  'meyungs',
#  'pauini',
#  'nueva gerona',
#  'clyde river',
#  'maniitsoq',
#  'bud',
#  'severnoye',
#  'talcahuano',
#  'chumikan',
#  'ancud',
#  'leningradskiy',
#  'katsuura',
#  'qaanaaq',
#  'oruro',
#  'mancio lima',
#  'sambava',
#  'attawapiskat',
#  'balod',
#  'mehamn',
#  'harper',
#  'tongchuan',
#  'nortelandia',
#  'svetlaya',
#  'los llanos de aridane',
#  'san carlos de bariloche',
#  'la palma',
#  'kondinskoye',
#  'oussouye',
#  'upernavik',
#  'kawalu',
#  'hofn',
#  'khatanga',
#  'anadyr',
#  'tabas',
#  'mathbaria',
#  'faro',
#  'matto',
#  'padang',
#  'kichmengskiy gorodok',
#  'talnakh',
#  'banda aceh',
#  'yakeshi',
#  'pushkinskiye gory',
#  'teknaf',
#  'chokwe',
#  'san patricio',
#  'robertsport',
#  'panjwin',
#  'alyangula',
#  'harqalah',
#  'lompoc',
#  'pacific grove',
#  'sao jose da coroa grande',
#  'urumqi',
#  'santa marta',
#  'warqla',
#  'luderitz',
#  'kuusamo',
#  'viransehir',
#  'bairiki',
#  'pevek',
#  'taltal',
#  'guane',
#  'mogadishu',
#  'terra santa',
#  'san ramon',
#  'manicore',
#  'esqueda',
#  'meulaboh',
#  'sakakah',
#  'numata',
#  'merauke',
#  'vaitupu',
#  'tuatapere',
#  'amderma',
#  'marshfield',
#  'salalah',
#  'skreia',
#  'nikolskoye',
#  'carballo',
#  'clarence town',
#  'buraydah',
#  'beringovskiy',
#  'tamboril',
#  'great falls',
#  'soyo',
#  'nemuro',
#  'geraldton',
#  'noto',
#  'beni',
#  'grand gaube',
#  'saldanha',
#  'iskateley',
#  'avarua',
#  'coquimbo',
#  'ornskoldsvik',
#  'honolulu',
#  'new norfolk',
#  'vila velha',
#  'paita',
#  'coolum beach',
#  'portobelo',
#  'halifax',
#  'westport',
#  'kedrovyy',
#  'mahanoro',
#  'abu dhabi',
#  'kaitangata',
#  'caravelas',
#  'arlit',
#  'akonolinga',
#  'teya',
#  'chokurdakh',
#  'dolbeau',
#  'iralaya',
#  'san buenaventura',
#  'hasaki',
#  'sobolevo',
#  'aykhal',
#  'ekhabi',
#  'nanortalik',
#  'nguiu',
#  'bathurst',
#  'faya',
#  'shizunai',
#  'katiola',
#  'seoul',
#  'qaqortoq',
#  'espanola',
#  'hualmay',
#  'esmeralda',
#  'acapulco',
#  'shingu',
#  'mahajanga',
#  'troitskoye',
#  'maanshan',
#  'beloha',
#  'wagga wagga',
#  'namibe',
#  'evensk',
#  'buena vista',
#  'palencia',
#  'bhalki',
#  'tasiilaq',
#  'sitka',
#  'baft',
#  'bumba',
#  'tual',
#  'raga',
#  'tura',
#  'swan hill',
#  'burlington',
#  'sribne',
#  'chapleau',
#  'maarianhamina',
#  'oktyabrskoye',
#  'saint-augustin',
#  'marcona',
#  'ixtapa',
#  'uvira',
#  'kutum',
#  'mishan',
#  'jacqueville',
#  'cidreira',
#  'antalaha',
#  'lorengau',
#  'naftah',
#  'byron bay',
#  'urcos',
#  'ligayan',
#  'lata',
#  'jarjis',
#  'shahr-e babak',
#  'bubaque',
#  'det udom',
#  'pimentel',
#  'santa luzia',
#  'bonfim',
#  'jalu',
#  'boddam',
#  'cockburn town',
#  'robinson',
#  'alta floresta',
#  'port blair',
#  'grindavik',
#  'provideniya',
#  'bathsheba',
#  'sawakin',
#  'kedougou',
#  'mount darwin',
#  'dukat',
#  'port hedland',
#  'dingle',
#  'emerald',
#  'ohafia',
#  'martfu',
#  'olafsvik',
#  'kibungo',
#  'husavik',
#  'kushiro',
#  'hay river',
#  'rio tercero',
#  'tamiahua',
#  'hunza',
#  'shieli',
#  'preobrazheniye',
#  'ahipara',
#  'avera',
#  'victor harbor',
#  'sao filipe',
#  'havre-saint-pierre',
#  'tilichiki',
#  'aranos',
#  'ashta',
#  'dunga bunga',
#  'artyk',
#  'batagay-alyta',
#  'guerrero negro',
#  'rong kwang',
#  'san andres',
#  'lamar',
#  'souillac',
#  'yayva',
#  'camocim',
#  'orlik',
#  'bethel',
#  'vila do maio',
#  'melfi',
#  'savonlinna',
#  'kulhudhuffushi',
#  'omsukchan',
#  'coffeyville',
#  'fort nelson',
#  'port maria',
#  'samfya',
#  'vestmannaeyjar',
#  'tyshkivka',
#  'kem',
#  'mentok',
#  'bac lieu',
#  'teabo',
#  'zugdidi',
#  'umzimvubu',
#  'arona',
#  'kirakira',
#  'ilulissat',
#  'maua',
#  'taoudenni',
#  'puerto escondido',
#  'te anau',
#  'ibra',
#  'vardo',
#  'malinyi',
#  'honiara',
#  'yirol',
#  'port macquarie',
#  'port hawkesbury',
#  'egvekinot',
#  'valparaiso',
#  'chicomuselo',
#  'nantucket',
#  'capaccio',
#  'fukue',
#  'milingimbi',
#  'lazaro cardenas',
#  'tubruq',
#  'palu',
#  'aksarka',
#  'san diego de los banos',
#  'kayerkan',
#  'lashio',
#  'inverell',
#  'dokri',
#  'esperance',
#  'tancanhuitz',
#  'carnarvon',
#  'sahrak',
#  'nampula',
#  'naze',
#  'les escoumins',
#  'ambon',
#  'banjar',
#  'gizo',
#  'agarak',
#  'mapiripan',
#  'hamilton',
#  'nizhniy tsasuchey',
#  'noumea',
#  'camargo',
#  'asau',
#  'petropavlovsk-kamchatskiy',
#  'desnogorsk',
#  'sharjah',
#  'nabire',
#  'alofi',
#  'mumford',
#  'polaniec',
#  'guanica',
#  'ostrovnoy',
#  'seredka',
#  'sao felix do xingu',
#  'richards bay',
#  'churapcha',
#  'buariki',
#  'port hardy',
#  'fortuna',
#  'cagliliog',
#  'kaniama',
#  'luganville',
#  'nome',
#  'coos bay',
#  'palabuhanratu',
#  'cururupu',
#  'sumbe',
#  'salto',
#  'auki',
#  'trairi',
#  'pemangkat',
#  'port-gentil',
#  'vidim',
#  'ban pong',
#  'necochea',
#  'codrington',
#  'nam tha',
#  'natchez',
#  'biltine',
#  'nizhneyansk',
#  'wageningen',
#  'sarankhola',
#  'komsomolskiy',
#  'mairana',
#  'cape elizabeth',
#  'hovd',
#  'calatagan',
#  'kopavogur',
#  'college',
#  'rudnyy',
#  'penzance',
#  'roald',
#  'dicabisagan',
#  'nyuksenitsa',
#  'porangatu',
#  'airai',
#  'mayo',
#  'acarau',
#  'brae',
#  'gondanglegi',
#  'honningsvag',
#  'waipawa',
#  'hobyo',
#  'maragogi',
#  'zyryanka',
#  'sisimiut',
#  'jinchang',
#  'agadez',
#  'bronnoysund',
#  'bonavista',
#  'barbar',
#  'marovoay',
#  'sulangan',
#  'balikpapan',
#  'port shepstone',
#  'smithers',
#  'saint-georges',
#  'palimbang',
#  'standerton',
#  'balkanabat',
#  'grand baie',
#  'neiafu',
#  'nago',
#  'manggar',
#  'palmas bellas',
#  'ciudad guayana',
#  'japura',
#  'baijiantan',
#  'gat',
#  'menongue',
#  'srednekolymsk',
#  'cooma',
#  'russell',
#  'ginda',
#  'sataua',
#  'consuelo',
#  'khoy',
#  'north bend',
#  'quelimane',
#  'bocas del toro',
#  'broome',
#  'leshukonskoye',
#  'mafeteng',
#  'lavrentiya',
#  'rio gallegos',
#  'dorado',
#  'kargasok',
#  'chimoio',
#  'amuntai',
#  'jizan',
#  'lagoa',
#  'severo-kurilsk',
#  'nishihara',
#  'ihosy',
#  'aste',
#  'gremyachye',
#  'bazarnyy syzgan',
#  'tukrah',
#  'formoso do araguaia',
#  'tocopilla',
#  'birpur',
#  'karwar',
#  'cardston',
#  'hailey',
#  'axim',
#  'kargat',
#  'cayenne',
#  'luis correia',
#  'coruripe',
#  'brookings',
#  'floro',
#  'san vicente',
#  'oistins',
#  'aginskoye',
#  'atambua',
#  'ajaccio',
#  'inta',
#  'mutare',
#  'haines junction',
#  'lufkin',
#  'ust-kuyga',
#  'kamenka',
#  'kelme',
#  'morondava',
#  'toulepleu',
#  'damghan',
#  'gorin',
#  'nara',
#  'walvis bay',
#  'carthage',
#  'soledade',
#  'changli',
#  'ambilobe',
#  'oum hadjer',
#  'camana',
#  'karamay',
#  'boa vista',
#  'saint-ambroise',
#  'lufilufi',
#  'never',
#  'north royalton',
#  'winton',
#  'yaan',
#  'antofagasta',
#  'karamea',
#  'punta cardon',
#  'matagami',
#  'lipin bor',
#  'urengoy',
#  'rudraprayag',
#  'tazmalt',
#  'mezen',
#  'kalangala',
#  'andilamena',
#  'srivardhan',
#  'little current',
#  'yelizovo',
#  'tongren',
#  'camara de lobos',
#  'comodoro rivadavia',
#  'bonthe',
#  'zaysan',
#  'bikaner',
#  'ashoknagar',
#  'coahuayana',
#  'shache',
#  'yulara',
#  'melfort',
#  'louga',
#  'tumannyy',
#  'oyama',
#  'ikongo',
#  'rio grande',
#  'fort saint john',
#  'vakhrushev',
#  'kongolo',
#  'cuenca',
#  'siyabuswa',
#  'dovolnoye',
#  'rungata',
#  'andros town',
#  'dosso',
#  'guadalupe',
#  'bilibino',
#  'labuhan',
#  'erzin',
#  'bjornevatn',
#  'half moon bay',
#  'natal',
#  'maumere',
#  'havoysund',
#  'narsaq',
#  'mayumba',
#  'lasa',
#  'kolosovka',
#  'mushie',
#  'stromness',
#  'wichita falls',
#  'zyryanovskiy',
#  'zhuanghe',
#  'sangar',
#  'asosa',
#  'krasnogvardeyets',
#  'tabuk',
#  'talas',
#  'lakatoro',
#  'la ronge',
#  'ust-kan',
#  'santa maria',
#  'claveria',
#  'beian',
#  'paragominas',
#  'indramayu',
#  'bayanday',
#  'ouesso',
#  'vila franca do campo',
#  'shimoda',
#  'jumla',
#  'challakere',
#  'aflu',
#  'grand river south east',
#  'nauta',
#  'vanimo',
#  'isiro',
#  'sinop',
#  'zwedru',
#  'pyaozerskiy',
#  'apple valley',
#  'juneau',
#  'de-kastri',
#  'tyukalinsk',
#  'kharan',
#  'kupang',
#  'coari',
#  'meadow lake',
#  'christchurch',
#  'kochkurovo',
#  'nizwa',
#  'agapovka',
#  'khonuu',
#  'ryotsu',
#  'dunwoody',
#  'carandai',
#  'dallas',
#  'sitio novo do tocantins',
#  'bixby',
#  'puerto carreno',
#  'conceicao do araguaia',
#  'bababe',
#  'eyl',
#  'santo domingo',
#  'wahran',
#  'misratah',
#  'derzhavinsk',
#  'kaihua',
#  'sertania',
#  'cabanas',
#  'san ignacio',
#  'tabiauea',
#  'tidore',
#  'bondoukou',
#  'veinticinco de mayo',
#  'camden',
#  'kolokani',
#  'rantauprapat',
#  'barawe',
#  'mullaitivu',
#  'syasstroy',
#  'moron',
#  'batemans bay',
#  'denia',
#  'taylorville',
#  'macas',
#  'san salvo',
#  'fairview',
#  'bandundu',
#  'saryshagan',
#  'jistebnice',
#  'burns lake',
#  'altay',
#  'ketchikan',
#  'dong hoi',
#  'minna',
#  'kjollefjord',
#  'lolua',
#  'moen',
#  'toliary',
#  'isangel',
#  'bougouni',
#  'newport',
#  'eagle pass',
#  'yumen',
#  'champoton',
#  'dalvik',
#  'witu',
#  'santa isabel do rio negro',
#  'bayshore gardens',
#  'saurimo',
#  'riyadh',
#  'jacmel',
#  'usinsk',
#  'saint-francois',
#  'bedesa',
#  'miandrivazo',
#  'tsiroanomandidy',
#  'tete',
#  'bardiyah',
#  'yeletskiy',
#  'chanika']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=faf0b3a56ae8e1d08d219ca62c9931f9

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping..." + city + " " + str(i))
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | miranda de ebro
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | barroquinha
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | norman wells
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | saint anthony
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | ksenyevka
# City not found. Skipping...ksenyevka 12
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | tsihombe
# City not found. Skipping...tsihombe 15
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...barentsburg 16
# Processing Record 18 of Set 1 | maralal
# Processing Record 19 of Set 1 | kavaratti
# Processing Record 20 of Set 1 | qiyang
# Processing Record 21 of Set 1 | ulladulla
# Processing Record 22 of Set 1 | oros
# Processing Record 23 of Set 1 | puerto ayora
# Processing Record 24 of Set 1 | denpasar
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | tautira
# Processing Record 27 of Set 1 | hithadhoo
# Processing Record 28 of Set 1 | saskylakh
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | adrar
# Processing Record 33 of Set 1 | manzhouli
# Processing Record 34 of Set 1 | bluff
# Processing Record 35 of Set 1 | belushya guba
# City not found. Skipping...belushya guba 34
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...taolanaro 36
# Processing Record 38 of Set 1 | pisco
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | sibolga
# Processing Record 41 of Set 1 | torbay
# Processing Record 42 of Set 1 | korla
# Processing Record 43 of Set 1 | itumba
# Processing Record 44 of Set 1 | wanning
# Processing Record 45 of Set 1 | cherskiy
# Processing Record 46 of Set 1 | dunedin
# Processing Record 47 of Set 1 | tavda
# Processing Record 48 of Set 1 | cabedelo
# Processing Record 49 of Set 1 | sentyabrskiy
# City not found. Skipping...sentyabrskiy 48
# Processing Record 50 of Set 1 | neuquen
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | samusu
# City not found. Skipping...samusu 51
# Processing Record 3 of Set 2 | hami
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | sioux lookout
# Processing Record 6 of Set 2 | west bend
# Processing Record 7 of Set 2 | kruisfontein
# Processing Record 8 of Set 2 | usvyaty
# Processing Record 9 of Set 2 | victoria
# Processing Record 10 of Set 2 | marsh harbour
# Processing Record 11 of Set 2 | terbuny
# Processing Record 12 of Set 2 | yellowknife
# Processing Record 13 of Set 2 | whitehorse
# Processing Record 14 of Set 2 | atuona
# Processing Record 15 of Set 2 | chiang khong
# Processing Record 16 of Set 2 | baghdad
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...saleaula 66
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | mount gambier
# Processing Record 20 of Set 2 | rawson
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | constitucion
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | sylacauga
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | karratha
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | povenets
# Processing Record 31 of Set 2 | susangerd
# Processing Record 32 of Set 2 | suhbaatar
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | atar
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | inhambane
# Processing Record 38 of Set 2 | lac du bonnet
# Processing Record 39 of Set 2 | fernie
# Processing Record 40 of Set 2 | taksimo
# Processing Record 41 of Set 2 | busselton
# Processing Record 42 of Set 2 | belaya gora
# Processing Record 43 of Set 2 | priladozhskiy
# Processing Record 44 of Set 2 | yabrud
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...mys shmidta 94
# Processing Record 46 of Set 2 | barra patuca
# Processing Record 47 of Set 2 | ponta do sol
# Processing Record 48 of Set 2 | marawi
# Processing Record 49 of Set 2 | louisbourg
# City not found. Skipping...louisbourg 98
# Processing Record 50 of Set 2 | san cristobal
# Processing Record 1 of Set 3 | itambe
# Processing Record 2 of Set 3 | grootfontein
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | thunder bay
# Processing Record 5 of Set 3 | sabang
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | khorramshahr
# Processing Record 9 of Set 3 | pangnirtung
# Processing Record 10 of Set 3 | yumbe
# Processing Record 11 of Set 3 | bay city
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | flinders
# Processing Record 14 of Set 3 | khash
# Processing Record 15 of Set 3 | san policarpo
# Processing Record 16 of Set 3 | ingham
# Processing Record 17 of Set 3 | durazno
# Processing Record 18 of Set 3 | thompson
# Processing Record 19 of Set 3 | xining
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | arraial do cabo
# Processing Record 22 of Set 3 | tambovka
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | hihifo
# City not found. Skipping...hihifo 123
# Processing Record 25 of Set 3 | goderich
# Processing Record 26 of Set 3 | oranjemund
# Processing Record 27 of Set 3 | carutapera
# Processing Record 28 of Set 3 | tuktoyaktuk
# Processing Record 29 of Set 3 | saint george
# Processing Record 30 of Set 3 | songkhla
# Processing Record 31 of Set 3 | sinnamary
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | surgut
# Processing Record 34 of Set 3 | deputatskiy
# Processing Record 35 of Set 3 | nizhniy kuranakh
# Processing Record 36 of Set 3 | veraval
# Processing Record 37 of Set 3 | nakhon phanom
# Processing Record 38 of Set 3 | jilib
# Processing Record 39 of Set 3 | illoqqortoormiut
# City not found. Skipping...illoqqortoormiut 138
# Processing Record 40 of Set 3 | henties bay
# Processing Record 41 of Set 3 | hukuntsi
# Processing Record 42 of Set 3 | castro
# Processing Record 43 of Set 3 | klaksvik
# Processing Record 44 of Set 3 | lokoja
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | inirida
# Processing Record 47 of Set 3 | suffolk
# Processing Record 48 of Set 3 | quatre cocos
# Processing Record 49 of Set 3 | correntina
# Processing Record 50 of Set 3 | mount isa
# Processing Record 1 of Set 4 | dikson
# Processing Record 2 of Set 4 | champerico
# Processing Record 3 of Set 4 | singapore
# Processing Record 4 of Set 4 | tessalit
# Processing Record 5 of Set 4 | meyungs
# City not found. Skipping...meyungs 154
# Processing Record 6 of Set 4 | pauini
# Processing Record 7 of Set 4 | nueva gerona
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | maniitsoq
# Processing Record 10 of Set 4 | bud
# Processing Record 11 of Set 4 | severnoye
# Processing Record 12 of Set 4 | talcahuano
# Processing Record 13 of Set 4 | chumikan
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | katsuura
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | oruro
# Processing Record 19 of Set 4 | mancio lima
# Processing Record 20 of Set 4 | sambava
# Processing Record 21 of Set 4 | attawapiskat
# City not found. Skipping...attawapiskat 170
# Processing Record 22 of Set 4 | balod
# Processing Record 23 of Set 4 | mehamn
# Processing Record 24 of Set 4 | harper
# Processing Record 25 of Set 4 | tongchuan
# Processing Record 26 of Set 4 | nortelandia
# Processing Record 27 of Set 4 | svetlaya
# Processing Record 28 of Set 4 | los llanos de aridane
# Processing Record 29 of Set 4 | san carlos de bariloche
# Processing Record 30 of Set 4 | la palma
# Processing Record 31 of Set 4 | kondinskoye
# Processing Record 32 of Set 4 | oussouye
# Processing Record 33 of Set 4 | upernavik
# Processing Record 34 of Set 4 | kawalu
# Processing Record 35 of Set 4 | hofn
# Processing Record 36 of Set 4 | khatanga
# Processing Record 37 of Set 4 | anadyr
# Processing Record 38 of Set 4 | tabas
# Processing Record 39 of Set 4 | mathbaria
# Processing Record 40 of Set 4 | faro
# Processing Record 41 of Set 4 | matto
# City not found. Skipping...matto 190
# Processing Record 42 of Set 4 | padang
# Processing Record 43 of Set 4 | kichmengskiy gorodok
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | banda aceh
# Processing Record 46 of Set 4 | yakeshi
# Processing Record 47 of Set 4 | pushkinskiye gory
# Processing Record 48 of Set 4 | teknaf
# Processing Record 49 of Set 4 | chokwe
# Processing Record 50 of Set 4 | san patricio
# Processing Record 1 of Set 5 | robertsport
# Processing Record 2 of Set 5 | panjwin
# City not found. Skipping...panjwin 201
# Processing Record 3 of Set 5 | alyangula
# Processing Record 4 of Set 5 | harqalah
# Processing Record 5 of Set 5 | lompoc
# Processing Record 6 of Set 5 | pacific grove
# Processing Record 7 of Set 5 | sao jose da coroa grande
# Processing Record 8 of Set 5 | urumqi
# Processing Record 9 of Set 5 | santa marta
# Processing Record 10 of Set 5 | warqla
# City not found. Skipping...warqla 209
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | kuusamo
# Processing Record 13 of Set 5 | viransehir
# Processing Record 14 of Set 5 | bairiki
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | taltal
# Processing Record 17 of Set 5 | guane
# Processing Record 18 of Set 5 | mogadishu
# Processing Record 19 of Set 5 | terra santa
# Processing Record 20 of Set 5 | san ramon
# Processing Record 21 of Set 5 | manicore
# Processing Record 22 of Set 5 | esqueda
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | sakakah
# Processing Record 25 of Set 5 | numata
# Processing Record 26 of Set 5 | merauke
# Processing Record 27 of Set 5 | vaitupu
# City not found. Skipping...vaitupu 226
# Processing Record 28 of Set 5 | tuatapere
# Processing Record 29 of Set 5 | amderma
# City not found. Skipping...amderma 228
# Processing Record 30 of Set 5 | marshfield
# Processing Record 31 of Set 5 | salalah
# Processing Record 32 of Set 5 | skreia
# Processing Record 33 of Set 5 | nikolskoye
# Processing Record 34 of Set 5 | carballo
# Processing Record 35 of Set 5 | clarence town
# Processing Record 36 of Set 5 | buraydah
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | tamboril
# Processing Record 39 of Set 5 | great falls
# Processing Record 40 of Set 5 | soyo
# Processing Record 41 of Set 5 | nemuro
# Processing Record 42 of Set 5 | geraldton
# Processing Record 43 of Set 5 | noto
# Processing Record 44 of Set 5 | beni
# Processing Record 45 of Set 5 | grand gaube
# Processing Record 46 of Set 5 | saldanha
# Processing Record 47 of Set 5 | iskateley
# Processing Record 48 of Set 5 | avarua
# Processing Record 49 of Set 5 | coquimbo
# Processing Record 50 of Set 5 | ornskoldsvik
# Processing Record 1 of Set 6 | honolulu
# Processing Record 2 of Set 6 | new norfolk
# Processing Record 3 of Set 6 | vila velha
# Processing Record 4 of Set 6 | paita
# Processing Record 5 of Set 6 | coolum beach
# Processing Record 6 of Set 6 | portobelo
# Processing Record 7 of Set 6 | halifax
# Processing Record 8 of Set 6 | westport
# Processing Record 9 of Set 6 | kedrovyy
# Processing Record 10 of Set 6 | mahanoro
# Processing Record 11 of Set 6 | abu dhabi
# Processing Record 12 of Set 6 | kaitangata
# Processing Record 13 of Set 6 | caravelas
# Processing Record 14 of Set 6 | arlit
# Processing Record 15 of Set 6 | akonolinga
# Processing Record 16 of Set 6 | teya
# Processing Record 17 of Set 6 | chokurdakh
# Processing Record 18 of Set 6 | dolbeau
# City not found. Skipping...dolbeau 267
# Processing Record 19 of Set 6 | iralaya
# Processing Record 20 of Set 6 | san buenaventura
# Processing Record 21 of Set 6 | hasaki
# Processing Record 22 of Set 6 | sobolevo
# Processing Record 23 of Set 6 | aykhal
# Processing Record 24 of Set 6 | ekhabi
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | nguiu
# City not found. Skipping...nguiu 275
# Processing Record 27 of Set 6 | bathurst
# Processing Record 28 of Set 6 | faya
# Processing Record 29 of Set 6 | shizunai
# Processing Record 30 of Set 6 | katiola
# Processing Record 31 of Set 6 | seoul
# Processing Record 32 of Set 6 | qaqortoq
# Processing Record 33 of Set 6 | espanola
# Processing Record 34 of Set 6 | hualmay
# Processing Record 35 of Set 6 | esmeralda
# Processing Record 36 of Set 6 | acapulco
# Processing Record 37 of Set 6 | shingu
# Processing Record 38 of Set 6 | mahajanga
# Processing Record 39 of Set 6 | troitskoye
# Processing Record 40 of Set 6 | maanshan
# Processing Record 41 of Set 6 | beloha
# Processing Record 42 of Set 6 | wagga wagga
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | evensk
# Processing Record 45 of Set 6 | buena vista
# Processing Record 46 of Set 6 | palencia
# Processing Record 47 of Set 6 | bhalki
# Processing Record 48 of Set 6 | tasiilaq
# Processing Record 49 of Set 6 | sitka
# Processing Record 50 of Set 6 | baft
# Processing Record 1 of Set 7 | bumba
# Processing Record 2 of Set 7 | tual
# Processing Record 3 of Set 7 | raga
# Processing Record 4 of Set 7 | tura
# Processing Record 5 of Set 7 | swan hill
# Processing Record 6 of Set 7 | burlington
# Processing Record 7 of Set 7 | sribne
# Processing Record 8 of Set 7 | chapleau
# Processing Record 9 of Set 7 | maarianhamina
# Processing Record 10 of Set 7 | oktyabrskoye
# Processing Record 11 of Set 7 | saint-augustin
# Processing Record 12 of Set 7 | marcona
# City not found. Skipping...marcona 311
# Processing Record 13 of Set 7 | ixtapa
# Processing Record 14 of Set 7 | uvira
# Processing Record 15 of Set 7 | kutum
# Processing Record 16 of Set 7 | mishan
# Processing Record 17 of Set 7 | jacqueville
# Processing Record 18 of Set 7 | cidreira
# Processing Record 19 of Set 7 | antalaha
# Processing Record 20 of Set 7 | lorengau
# Processing Record 21 of Set 7 | naftah
# City not found. Skipping...naftah 320
# Processing Record 22 of Set 7 | byron bay
# Processing Record 23 of Set 7 | urcos
# Processing Record 24 of Set 7 | ligayan
# Processing Record 25 of Set 7 | lata
# Processing Record 26 of Set 7 | jarjis
# City not found. Skipping...jarjis 325
# Processing Record 27 of Set 7 | shahr-e babak
# Processing Record 28 of Set 7 | bubaque
# Processing Record 29 of Set 7 | det udom
# Processing Record 30 of Set 7 | pimentel
# Processing Record 31 of Set 7 | santa luzia
# Processing Record 32 of Set 7 | bonfim
# Processing Record 33 of Set 7 | jalu
# Processing Record 34 of Set 7 | boddam
# Processing Record 35 of Set 7 | cockburn town
# Processing Record 36 of Set 7 | robinson
# Processing Record 37 of Set 7 | alta floresta
# Processing Record 38 of Set 7 | port blair
# Processing Record 39 of Set 7 | grindavik
# Processing Record 40 of Set 7 | provideniya
# Processing Record 41 of Set 7 | bathsheba
# Processing Record 42 of Set 7 | sawakin
# Processing Record 43 of Set 7 | kedougou
# Processing Record 44 of Set 7 | mount darwin
# Processing Record 45 of Set 7 | dukat
# Processing Record 46 of Set 7 | port hedland
# Processing Record 47 of Set 7 | dingle
# Processing Record 48 of Set 7 | emerald
# Processing Record 49 of Set 7 | ohafia
# Processing Record 50 of Set 7 | martfu
# City not found. Skipping...martfu 349
# Processing Record 1 of Set 8 | olafsvik
# Processing Record 2 of Set 8 | kibungo
# Processing Record 3 of Set 8 | husavik
# Processing Record 4 of Set 8 | kushiro
# Processing Record 5 of Set 8 | hay river
# Processing Record 6 of Set 8 | rio tercero
# Processing Record 7 of Set 8 | tamiahua
# Processing Record 8 of Set 8 | hunza
# City not found. Skipping...hunza 357
# Processing Record 9 of Set 8 | shieli
# Processing Record 10 of Set 8 | preobrazheniye
# Processing Record 11 of Set 8 | ahipara
# Processing Record 12 of Set 8 | avera
# Processing Record 13 of Set 8 | victor harbor
# Processing Record 14 of Set 8 | sao filipe
# Processing Record 15 of Set 8 | havre-saint-pierre
# Processing Record 16 of Set 8 | tilichiki
# Processing Record 17 of Set 8 | aranos
# Processing Record 18 of Set 8 | ashta
# Processing Record 19 of Set 8 | dunga bunga
# Processing Record 20 of Set 8 | artyk
# City not found. Skipping...artyk 369
# Processing Record 21 of Set 8 | batagay-alyta
# Processing Record 22 of Set 8 | guerrero negro
# Processing Record 23 of Set 8 | rong kwang
# Processing Record 24 of Set 8 | san andres
# Processing Record 25 of Set 8 | lamar
# Processing Record 26 of Set 8 | souillac
# Processing Record 27 of Set 8 | yayva
# Processing Record 28 of Set 8 | camocim
# Processing Record 29 of Set 8 | orlik
# Processing Record 30 of Set 8 | bethel
# Processing Record 31 of Set 8 | vila do maio
# Processing Record 32 of Set 8 | melfi
# Processing Record 33 of Set 8 | savonlinna
# Processing Record 34 of Set 8 | kulhudhuffushi
# Processing Record 35 of Set 8 | omsukchan
# Processing Record 36 of Set 8 | coffeyville
# Processing Record 37 of Set 8 | fort nelson
# Processing Record 38 of Set 8 | port maria
# Processing Record 39 of Set 8 | samfya
# Processing Record 40 of Set 8 | vestmannaeyjar
# Processing Record 41 of Set 8 | tyshkivka
# Processing Record 42 of Set 8 | kem
# Processing Record 43 of Set 8 | mentok
# City not found. Skipping...mentok 392
# Processing Record 44 of Set 8 | bac lieu
# Processing Record 45 of Set 8 | teabo
# Processing Record 46 of Set 8 | zugdidi
# Processing Record 47 of Set 8 | umzimvubu
# City not found. Skipping...umzimvubu 396
# Processing Record 48 of Set 8 | arona
# Processing Record 49 of Set 8 | kirakira
# Processing Record 50 of Set 8 | ilulissat
# Processing Record 1 of Set 9 | maua
# Processing Record 2 of Set 9 | taoudenni
# Processing Record 3 of Set 9 | puerto escondido
# Processing Record 4 of Set 9 | te anau
# Processing Record 5 of Set 9 | ibra
# Processing Record 6 of Set 9 | vardo
# Processing Record 7 of Set 9 | malinyi
# Processing Record 8 of Set 9 | honiara
# Processing Record 9 of Set 9 | yirol
# City not found. Skipping...yirol 408
# Processing Record 10 of Set 9 | port macquarie
# Processing Record 11 of Set 9 | port hawkesbury
# Processing Record 12 of Set 9 | egvekinot
# Processing Record 13 of Set 9 | valparaiso
# Processing Record 14 of Set 9 | chicomuselo
# Processing Record 15 of Set 9 | nantucket
# Processing Record 16 of Set 9 | capaccio
# Processing Record 17 of Set 9 | fukue
# Processing Record 18 of Set 9 | milingimbi
# City not found. Skipping...milingimbi 417
# Processing Record 19 of Set 9 | lazaro cardenas
# Processing Record 20 of Set 9 | tubruq
# City not found. Skipping...tubruq 419
# Processing Record 21 of Set 9 | palu
# Processing Record 22 of Set 9 | aksarka
# Processing Record 23 of Set 9 | san diego de los banos
# Processing Record 24 of Set 9 | kayerkan
# Processing Record 25 of Set 9 | lashio
# Processing Record 26 of Set 9 | inverell
# Processing Record 27 of Set 9 | dokri
# Processing Record 28 of Set 9 | esperance
# Processing Record 29 of Set 9 | tancanhuitz
# Processing Record 30 of Set 9 | carnarvon
# Processing Record 31 of Set 9 | sahrak
# City not found. Skipping...sahrak 430
# Processing Record 32 of Set 9 | nampula
# Processing Record 33 of Set 9 | naze
# Processing Record 34 of Set 9 | les escoumins
# Processing Record 35 of Set 9 | ambon
# Processing Record 36 of Set 9 | banjar
# Processing Record 37 of Set 9 | gizo
# Processing Record 38 of Set 9 | agarak
# Processing Record 39 of Set 9 | mapiripan
# Processing Record 40 of Set 9 | hamilton
# Processing Record 41 of Set 9 | nizhniy tsasuchey
# Processing Record 42 of Set 9 | noumea
# Processing Record 43 of Set 9 | camargo
# Processing Record 44 of Set 9 | asau
# Processing Record 45 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 9 | desnogorsk
# Processing Record 47 of Set 9 | sharjah
# Processing Record 48 of Set 9 | nabire
# Processing Record 49 of Set 9 | alofi
# Processing Record 50 of Set 9 | mumford
# Processing Record 1 of Set 10 | polaniec
# Processing Record 2 of Set 10 | guanica
# Processing Record 3 of Set 10 | ostrovnoy
# Processing Record 4 of Set 10 | seredka
# Processing Record 5 of Set 10 | sao felix do xingu
# Processing Record 6 of Set 10 | richards bay
# Processing Record 7 of Set 10 | churapcha
# Processing Record 8 of Set 10 | buariki
# City not found. Skipping...buariki 457
# Processing Record 9 of Set 10 | port hardy
# Processing Record 10 of Set 10 | fortuna
# Processing Record 11 of Set 10 | cagliliog
# Processing Record 12 of Set 10 | kaniama
# Processing Record 13 of Set 10 | luganville
# Processing Record 14 of Set 10 | nome
# Processing Record 15 of Set 10 | coos bay
# Processing Record 16 of Set 10 | palabuhanratu
# City not found. Skipping...palabuhanratu 465
# Processing Record 17 of Set 10 | cururupu
# Processing Record 18 of Set 10 | sumbe
# Processing Record 19 of Set 10 | salto
# Processing Record 20 of Set 10 | auki
# Processing Record 21 of Set 10 | trairi
# Processing Record 22 of Set 10 | pemangkat
# Processing Record 23 of Set 10 | port-gentil
# Processing Record 24 of Set 10 | vidim
# Processing Record 25 of Set 10 | ban pong
# Processing Record 26 of Set 10 | necochea
# Processing Record 27 of Set 10 | codrington
# Processing Record 28 of Set 10 | nam tha
# City not found. Skipping...nam tha 477
# Processing Record 29 of Set 10 | natchez
# Processing Record 30 of Set 10 | biltine
# Processing Record 31 of Set 10 | nizhneyansk
# City not found. Skipping...nizhneyansk 480
# Processing Record 32 of Set 10 | wageningen
# Processing Record 33 of Set 10 | sarankhola
# Processing Record 34 of Set 10 | komsomolskiy
# Processing Record 35 of Set 10 | mairana
# Processing Record 36 of Set 10 | cape elizabeth
# City not found. Skipping...cape elizabeth 485
# Processing Record 37 of Set 10 | hovd
# Processing Record 38 of Set 10 | calatagan
# Processing Record 39 of Set 10 | kopavogur
# Processing Record 40 of Set 10 | college
# Processing Record 41 of Set 10 | rudnyy
# Processing Record 42 of Set 10 | penzance
# Processing Record 43 of Set 10 | roald
# Processing Record 44 of Set 10 | dicabisagan
# Processing Record 45 of Set 10 | nyuksenitsa
# Processing Record 46 of Set 10 | porangatu
# Processing Record 47 of Set 10 | airai
# Processing Record 48 of Set 10 | mayo
# Processing Record 49 of Set 10 | acarau
# Processing Record 50 of Set 10 | brae
# Processing Record 1 of Set 11 | gondanglegi
# Processing Record 2 of Set 11 | honningsvag
# Processing Record 3 of Set 11 | waipawa
# Processing Record 4 of Set 11 | hobyo
# Processing Record 5 of Set 11 | maragogi
# Processing Record 6 of Set 11 | zyryanka
# Processing Record 7 of Set 11 | sisimiut
# Processing Record 8 of Set 11 | jinchang
# Processing Record 9 of Set 11 | agadez
# Processing Record 10 of Set 11 | bronnoysund
# Processing Record 11 of Set 11 | bonavista
# Processing Record 12 of Set 11 | barbar
# City not found. Skipping...barbar 511
# Processing Record 13 of Set 11 | marovoay
# Processing Record 14 of Set 11 | sulangan
# Processing Record 15 of Set 11 | balikpapan
# Processing Record 16 of Set 11 | port shepstone
# Processing Record 17 of Set 11 | smithers
# Processing Record 18 of Set 11 | saint-georges
# Processing Record 19 of Set 11 | palimbang
# Processing Record 20 of Set 11 | standerton
# Processing Record 21 of Set 11 | balkanabat
# Processing Record 22 of Set 11 | grand baie
# Processing Record 23 of Set 11 | neiafu
# Processing Record 24 of Set 11 | nago
# Processing Record 25 of Set 11 | manggar
# Processing Record 26 of Set 11 | palmas bellas
# Processing Record 27 of Set 11 | ciudad guayana
# Processing Record 28 of Set 11 | japura
# Processing Record 29 of Set 11 | baijiantan
# Processing Record 30 of Set 11 | gat
# Processing Record 31 of Set 11 | menongue
# Processing Record 32 of Set 11 | srednekolymsk
# Processing Record 33 of Set 11 | cooma
# Processing Record 34 of Set 11 | russell
# Processing Record 35 of Set 11 | ginda
# Processing Record 36 of Set 11 | sataua
# City not found. Skipping...sataua 535
# Processing Record 37 of Set 11 | consuelo
# Processing Record 38 of Set 11 | khoy
# Processing Record 39 of Set 11 | north bend
# Processing Record 40 of Set 11 | quelimane
# Processing Record 41 of Set 11 | bocas del toro
# Processing Record 42 of Set 11 | broome
# Processing Record 43 of Set 11 | leshukonskoye
# Processing Record 44 of Set 11 | mafeteng
# Processing Record 45 of Set 11 | lavrentiya
# Processing Record 46 of Set 11 | rio gallegos
# Processing Record 47 of Set 11 | dorado
# Processing Record 48 of Set 11 | kargasok
# Processing Record 49 of Set 11 | chimoio
# Processing Record 50 of Set 11 | amuntai
# Processing Record 1 of Set 12 | jizan
# Processing Record 2 of Set 12 | lagoa
# Processing Record 3 of Set 12 | severo-kurilsk
# Processing Record 4 of Set 12 | nishihara
# Processing Record 5 of Set 12 | ihosy
# Processing Record 6 of Set 12 | aste
# Processing Record 7 of Set 12 | gremyachye
# City not found. Skipping...gremyachye 556
# Processing Record 8 of Set 12 | bazarnyy syzgan
# Processing Record 9 of Set 12 | tukrah
# Processing Record 10 of Set 12 | formoso do araguaia
# City not found. Skipping...formoso do araguaia 559
# Processing Record 11 of Set 12 | tocopilla
# Processing Record 12 of Set 12 | birpur
# Processing Record 13 of Set 12 | karwar
# Processing Record 14 of Set 12 | cardston
# Processing Record 15 of Set 12 | hailey
# Processing Record 16 of Set 12 | axim
# Processing Record 17 of Set 12 | kargat
# Processing Record 18 of Set 12 | cayenne
# Processing Record 19 of Set 12 | luis correia
# Processing Record 20 of Set 12 | coruripe
# Processing Record 21 of Set 12 | brookings
# Processing Record 22 of Set 12 | floro
# Processing Record 23 of Set 12 | san vicente
# Processing Record 24 of Set 12 | oistins
# Processing Record 25 of Set 12 | aginskoye
# Processing Record 26 of Set 12 | atambua
# Processing Record 27 of Set 12 | ajaccio
# Processing Record 28 of Set 12 | inta
# Processing Record 29 of Set 12 | mutare
# Processing Record 30 of Set 12 | haines junction
# Processing Record 31 of Set 12 | lufkin
# Processing Record 32 of Set 12 | ust-kuyga
# Processing Record 33 of Set 12 | kamenka
# Processing Record 34 of Set 12 | kelme
# Processing Record 35 of Set 12 | morondava
# Processing Record 36 of Set 12 | toulepleu
# City not found. Skipping...toulepleu 585
# Processing Record 37 of Set 12 | damghan
# Processing Record 38 of Set 12 | gorin
# Processing Record 39 of Set 12 | nara
# Processing Record 40 of Set 12 | walvis bay
# Processing Record 41 of Set 12 | carthage
# Processing Record 42 of Set 12 | soledade
# Processing Record 43 of Set 12 | changli
# Processing Record 44 of Set 12 | ambilobe
# Processing Record 45 of Set 12 | oum hadjer
# Processing Record 46 of Set 12 | camana
# Processing Record 47 of Set 12 | karamay
# City not found. Skipping...karamay 596
# Processing Record 48 of Set 12 | boa vista
# Processing Record 49 of Set 12 | saint-ambroise
# Processing Record 50 of Set 12 | lufilufi
# Processing Record 1 of Set 13 | never
# Processing Record 2 of Set 13 | north royalton
# Processing Record 3 of Set 13 | winton
# Processing Record 4 of Set 13 | yaan
# Processing Record 5 of Set 13 | antofagasta
# Processing Record 6 of Set 13 | karamea
# City not found. Skipping...karamea 605
# Processing Record 7 of Set 13 | punta cardon
# Processing Record 8 of Set 13 | matagami
# Processing Record 9 of Set 13 | lipin bor
# Processing Record 10 of Set 13 | urengoy
# Processing Record 11 of Set 13 | rudraprayag
# Processing Record 12 of Set 13 | tazmalt
# Processing Record 13 of Set 13 | mezen
# Processing Record 14 of Set 13 | kalangala
# Processing Record 15 of Set 13 | andilamena
# Processing Record 16 of Set 13 | srivardhan
# Processing Record 17 of Set 13 | little current
# Processing Record 18 of Set 13 | yelizovo
# Processing Record 19 of Set 13 | tongren
# Processing Record 20 of Set 13 | camara de lobos
# Processing Record 21 of Set 13 | comodoro rivadavia
# Processing Record 22 of Set 13 | bonthe
# Processing Record 23 of Set 13 | zaysan
# Processing Record 24 of Set 13 | bikaner
# Processing Record 25 of Set 13 | ashoknagar
# Processing Record 26 of Set 13 | coahuayana
# Processing Record 27 of Set 13 | shache
# Processing Record 28 of Set 13 | yulara
# Processing Record 29 of Set 13 | melfort
# Processing Record 30 of Set 13 | louga
# Processing Record 31 of Set 13 | tumannyy
# City not found. Skipping...tumannyy 630
# Processing Record 32 of Set 13 | oyama
# Processing Record 33 of Set 13 | ikongo
# Processing Record 34 of Set 13 | rio grande
# Processing Record 35 of Set 13 | fort saint john
# City not found. Skipping...fort saint john 634
# Processing Record 36 of Set 13 | vakhrushev
# Processing Record 37 of Set 13 | kongolo
# Processing Record 38 of Set 13 | cuenca
# Processing Record 39 of Set 13 | siyabuswa
# Processing Record 40 of Set 13 | dovolnoye
# Processing Record 41 of Set 13 | rungata
# City not found. Skipping...rungata 640
# Processing Record 42 of Set 13 | andros town
# Processing Record 43 of Set 13 | dosso
# Processing Record 44 of Set 13 | guadalupe
# Processing Record 45 of Set 13 | bilibino
# Processing Record 46 of Set 13 | labuhan
# Processing Record 47 of Set 13 | erzin
# Processing Record 48 of Set 13 | bjornevatn
# Processing Record 49 of Set 13 | half moon bay
# Processing Record 50 of Set 13 | natal
# Processing Record 1 of Set 14 | maumere
# Processing Record 2 of Set 14 | havoysund
# Processing Record 3 of Set 14 | narsaq
# Processing Record 4 of Set 14 | mayumba
# Processing Record 5 of Set 14 | lasa
# Processing Record 6 of Set 14 | kolosovka
# Processing Record 7 of Set 14 | mushie
# Processing Record 8 of Set 14 | stromness
# Processing Record 9 of Set 14 | wichita falls
# Processing Record 10 of Set 14 | zyryanovskiy
# City not found. Skipping...zyryanovskiy 659
# Processing Record 11 of Set 14 | zhuanghe
# Processing Record 12 of Set 14 | sangar
# Processing Record 13 of Set 14 | asosa
# Processing Record 14 of Set 14 | krasnogvardeyets
# Processing Record 15 of Set 14 | tabuk
# Processing Record 16 of Set 14 | talas
# Processing Record 17 of Set 14 | lakatoro
# Processing Record 18 of Set 14 | la ronge
# Processing Record 19 of Set 14 | ust-kan
# Processing Record 20 of Set 14 | santa maria
# Processing Record 21 of Set 14 | claveria
# Processing Record 22 of Set 14 | beian
# Processing Record 23 of Set 14 | paragominas
# Processing Record 24 of Set 14 | indramayu
# Processing Record 25 of Set 14 | bayanday
# Processing Record 26 of Set 14 | ouesso
# Processing Record 27 of Set 14 | vila franca do campo
# Processing Record 28 of Set 14 | shimoda
# Processing Record 29 of Set 14 | jumla
# Processing Record 30 of Set 14 | challakere
# Processing Record 31 of Set 14 | aflu
# City not found. Skipping...aflu 680
# Processing Record 32 of Set 14 | grand river south east
# City not found. Skipping...grand river south east 681
# Processing Record 33 of Set 14 | nauta
# Processing Record 34 of Set 14 | vanimo
# Processing Record 35 of Set 14 | isiro
# Processing Record 36 of Set 14 | sinop
# Processing Record 37 of Set 14 | zwedru
# Processing Record 38 of Set 14 | pyaozerskiy
# Processing Record 39 of Set 14 | apple valley
# Processing Record 40 of Set 14 | juneau
# Processing Record 41 of Set 14 | de-kastri
# Processing Record 42 of Set 14 | tyukalinsk
# Processing Record 43 of Set 14 | kharan
# Processing Record 44 of Set 14 | kupang
# Processing Record 45 of Set 14 | coari
# Processing Record 46 of Set 14 | meadow lake
# Processing Record 47 of Set 14 | christchurch
# Processing Record 48 of Set 14 | kochkurovo
# Processing Record 49 of Set 14 | nizwa
# Processing Record 50 of Set 14 | agapovka
# Processing Record 1 of Set 15 | khonuu
# City not found. Skipping...khonuu 700
# Processing Record 2 of Set 15 | ryotsu
# Processing Record 3 of Set 15 | dunwoody
# Processing Record 4 of Set 15 | carandai
# Processing Record 5 of Set 15 | dallas
# Processing Record 6 of Set 15 | sitio novo do tocantins
# Processing Record 7 of Set 15 | bixby
# Processing Record 8 of Set 15 | puerto carreno
# Processing Record 9 of Set 15 | conceicao do araguaia
# Processing Record 10 of Set 15 | bababe
# City not found. Skipping...bababe 709
# Processing Record 11 of Set 15 | eyl
# Processing Record 12 of Set 15 | santo domingo
# Processing Record 13 of Set 15 | wahran
# City not found. Skipping...wahran 712
# Processing Record 14 of Set 15 | misratah
# Processing Record 15 of Set 15 | derzhavinsk
# Processing Record 16 of Set 15 | kaihua
# Processing Record 17 of Set 15 | sertania
# Processing Record 18 of Set 15 | cabanas
# Processing Record 19 of Set 15 | san ignacio
# Processing Record 20 of Set 15 | tabiauea
# City not found. Skipping...tabiauea 719
# Processing Record 21 of Set 15 | tidore
# City not found. Skipping...tidore 720
# Processing Record 22 of Set 15 | bondoukou
# Processing Record 23 of Set 15 | veinticinco de mayo
# Processing Record 24 of Set 15 | camden
# Processing Record 25 of Set 15 | kolokani
# Processing Record 26 of Set 15 | rantauprapat
# Processing Record 27 of Set 15 | barawe
# City not found. Skipping...barawe 726
# Processing Record 28 of Set 15 | mullaitivu
# City not found. Skipping...mullaitivu 727
# Processing Record 29 of Set 15 | syasstroy
# Processing Record 30 of Set 15 | moron
# Processing Record 31 of Set 15 | batemans bay
# Processing Record 32 of Set 15 | denia
# Processing Record 33 of Set 15 | taylorville
# Processing Record 34 of Set 15 | macas
# Processing Record 35 of Set 15 | san salvo
# Processing Record 36 of Set 15 | fairview
# Processing Record 37 of Set 15 | bandundu
# Processing Record 38 of Set 15 | saryshagan
# City not found. Skipping...saryshagan 737
# Processing Record 39 of Set 15 | jistebnice
# Processing Record 40 of Set 15 | burns lake
# Processing Record 41 of Set 15 | altay
# Processing Record 42 of Set 15 | ketchikan
# Processing Record 43 of Set 15 | dong hoi
# Processing Record 44 of Set 15 | minna
# Processing Record 45 of Set 15 | kjollefjord
# Processing Record 46 of Set 15 | lolua
# City not found. Skipping...lolua 745
# Processing Record 47 of Set 15 | moen
# Processing Record 48 of Set 15 | toliary
# City not found. Skipping...toliary 747
# Processing Record 49 of Set 15 | isangel
# Processing Record 50 of Set 15 | bougouni
# Processing Record 1 of Set 16 | newport
# Processing Record 2 of Set 16 | eagle pass
# Processing Record 3 of Set 16 | yumen
# Processing Record 4 of Set 16 | champoton
# Processing Record 5 of Set 16 | dalvik
# Processing Record 6 of Set 16 | witu
# Processing Record 7 of Set 16 | santa isabel do rio negro
# Processing Record 8 of Set 16 | bayshore gardens
# Processing Record 9 of Set 16 | saurimo
# Processing Record 10 of Set 16 | riyadh
# Processing Record 11 of Set 16 | jacmel
# Processing Record 12 of Set 16 | usinsk
# Processing Record 13 of Set 16 | saint-francois
# Processing Record 14 of Set 16 | bedesa
# Processing Record 15 of Set 16 | miandrivazo
# Processing Record 16 of Set 16 | tsiroanomandidy
# Processing Record 17 of Set 16 | tete
# Processing Record 18 of Set 16 | bardiyah
# Processing Record 19 of Set 16 | yeletskiy
# City not found. Skipping...yeletskiy 768
# Processing Record 20 of Set 16 | chanika
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 708

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Miranda De Ebro      ES  42.6865   -2.9470     45.00        76          75
# 1          Rikitea      PF -23.1203 -134.9692     79.50        70           0
# 2            Vaini      TO -21.2000 -175.2000     86.00        79          75
# 3      Barroquinha      BR  -3.0189  -41.1361     76.95        81         100
# 4   Saint-Philippe      RE -21.3585   55.7679     78.80        65           0
# 5        Jamestown      US  42.0970  -79.2353     17.60        79           1
# 6            Kapaa      US  22.0752 -159.3190     77.00        69          75
# 7     Norman Wells      CA  65.2820 -126.8329    -31.00        75          75
# 8   Ribeira Grande      PT  38.5167  -28.7000     63.16        91          97
# 9           Faanui      PF -16.4833 -151.7500     81.75        70          31
#
#    Wind Speed Current Description                 Date
# 0       11.50       broken clouds  2021-01-31 01:22:34
# 1       11.34           clear sky  2021-01-31 01:22:35
# 2       13.80       broken clouds  2021-01-31 01:20:19
# 3        5.68     overcast clouds  2021-01-31 01:22:35
# 4        8.05          light rain  2021-01-31 01:07:56
# 5        3.13           clear sky  2021-01-31 01:22:12
# 6       14.97          light rain  2021-01-31 01:22:35
# 7        3.31       broken clouds  2021-01-31 01:22:35
# 8       22.06     overcast clouds  2021-01-31 01:22:35
# 9        8.03    scattered clouds  2021-01-31 01:22:36

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
