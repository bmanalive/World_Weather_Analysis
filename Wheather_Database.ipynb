# %%
# Import the random module.
import random

# Import the NumPy module.
import numpy as np

# Import the Pandas module.
import pandas as pd

# Import the matplotlib.pyplot module.
import matplotlib.pyplot as plt

# Import citypy
from citipy import citipy

# %%
import importlib
importlib.reload(citipy)
# Out:
# <module 'citipy.citipy' from '/Users/Manuel/opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/citipy/citipy.py'>

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
cities
# Out:
# ['ushuaia',
#  'bacuit',
#  'castro',
#  'port alfred',
#  'zhigansk',
#  'lago da pedra',
#  'kolosovka',
#  'coquimbo',
#  'kampot',
#  'la ronge',
#  'ruatoria',
#  'albany',
#  'busselton',
#  'chokurdakh',
#  'beringovskiy',
#  'rikitea',
#  'vaini',
#  'clyde river',
#  'port lincoln',
#  'bethel',
#  'teahupoo',
#  'torbay',
#  'provideniya',
#  'guerrero negro',
#  'santa vitoria do palmar',
#  'illoqqortoormiut',
#  'kirakira',
#  'severo-kurilsk',
#  'bluff',
#  'marsh harbour',
#  'ankazoabo',
#  'lima',
#  'faanui',
#  'hobart',
#  'bara',
#  'nioro',
#  'vanimo',
#  'sembakung',
#  'kodinsk',
#  'punta arenas',
#  'amderma',
#  'kapaa',
#  'riyadh',
#  'bredasdorp',
#  'pevek',
#  'kruisfontein',
#  'atuona',
#  'palabuhanratu',
#  'worland',
#  'marawi',
#  'wahran',
#  'kropotkin',
#  'barentsburg',
#  'thompson',
#  'kodiak',
#  'bunia',
#  'vangazi',
#  'panlaitan',
#  'mount gambier',
#  'qaanaaq',
#  'dikson',
#  'mahebourg',
#  'ogaminana',
#  'port elizabeth',
#  'butaritari',
#  'puerto escondido',
#  'mataura',
#  'greenville',
#  'olavarria',
#  'carikar',
#  'tura',
#  'cidreira',
#  'souillac',
#  'kuche',
#  'kavieng',
#  'ponta do sol',
#  'omboue',
#  'sentyabrskiy',
#  'millet',
#  'high rock',
#  'sao sebastiao do passe',
#  'longyan',
#  'tahara',
#  'hovd',
#  'avarua',
#  'lebu',
#  'fairbanks',
#  'yuryevets',
#  'benguela',
#  'bargal',
#  'constitucion',
#  'mahon',
#  'paamiut',
#  'georgetown',
#  'buturlinovka',
#  'jamestown',
#  'khatanga',
#  'ogdensburg',
#  'lawrence',
#  'lermontovka',
#  'kiruna',
#  'nipawin',
#  'finschhafen',
#  'yellowknife',
#  'klaksvik',
#  'wau',
#  'liverpool',
#  'were ilu',
#  'acarau',
#  'avsyunino',
#  'christchurch',
#  'yokadouma',
#  'tonala',
#  'hambantota',
#  'dedovichi',
#  'phan rang',
#  'nosy varika',
#  'mar del plata',
#  'sechura',
#  'hermanus',
#  'mudanjiang',
#  'saint-philippe',
#  'leh',
#  'nikolskoye',
#  'puerto ayora',
#  'tautira',
#  'plainview',
#  'pemangkat',
#  'tasiilaq',
#  'dunedin',
#  'barrow',
#  'broome',
#  'codrington',
#  'sisimiut',
#  'chissamba',
#  'el molino',
#  'lata',
#  'tuktoyaktuk',
#  'cape town',
#  'salalah',
#  'yaya',
#  'arraial do cabo',
#  'attawapiskat',
#  'fortuna',
#  'lavrentiya',
#  'saint-pierre',
#  'taolanaro',
#  'grindavik',
#  'baruun-urt',
#  'daru',
#  'esperance',
#  'adrar',
#  'samalaeulu',
#  'san patricio',
#  'lerwick',
#  'bulgan',
#  'saskylakh',
#  'plettenberg bay',
#  'bighapur',
#  'ancud',
#  'lakhdenpokhya',
#  'nanortalik',
#  'maltahohe',
#  'hobyo',
#  'khagrachari',
#  'namibe',
#  'brae',
#  'maragogi',
#  'talnakh',
#  'ormara',
#  'kushima',
#  'bengkulu',
#  'belushya guba',
#  'makakilo city',
#  'tuatapere',
#  'sitka',
#  'namatanai',
#  'olafsvik',
#  'umm lajj',
#  'moerai',
#  'nyimba',
#  'egvekinot',
#  'shijak',
#  'victor harbor',
#  'krasnoselkup',
#  'saint-augustin',
#  'upernavik',
#  'caravelas',
#  'sao filipe',
#  'tsumeb',
#  'barawe',
#  'sabha',
#  'new norfolk',
#  'hilo',
#  'tiksi',
#  'lompoc',
#  'erzin',
#  'vostok',
#  'coihaique',
#  'ochakiv',
#  'leningradskiy',
#  'ketchikan',
#  'san vicente',
#  'samarai',
#  'boende',
#  'phalaborwa',
#  'norden',
#  'saldanha',
#  'sinnamary',
#  'cherskiy',
#  'macau',
#  'saint george',
#  'mwinilunga',
#  'vizinga',
#  'los llanos de aridane',
#  'iqaluit',
#  'vila velha',
#  'flinders',
#  'bosobolo',
#  'huarmey',
#  'hithadhoo',
#  'pisco',
#  'lixourion',
#  'itaguai',
#  'meadow lake',
#  'victoria',
#  'narsaq',
#  'jieshi',
#  'mitu',
#  'kalanguy',
#  'bambous virieux',
#  'chunoyar',
#  'batagay',
#  'east london',
#  'vaitupu',
#  'lethem',
#  'hasaki',
#  'ilulissat',
#  'portobelo',
#  'lumsden',
#  'mgandu',
#  'barrancabermeja',
#  'touros',
#  'kijang',
#  'dalbandin',
#  'mys shmidta',
#  'ambovombe',
#  'cap malheureux',
#  'bozeman',
#  'adeje',
#  'vercelli',
#  'manado',
#  'gandia',
#  'berlevag',
#  'lamar',
#  'chabahar',
#  'college',
#  'aldan',
#  'airai',
#  'kargil',
#  'georgiyevka',
#  'alofi',
#  'hearst',
#  'great falls',
#  'nevers',
#  'palembang',
#  'nishihara',
#  'empalme',
#  'banepa',
#  'statesboro',
#  'grand gaube',
#  'sulit',
#  'dudinka',
#  'presidencia roque saenz pena',
#  'bilma',
#  'rundu',
#  'pangnirtung',
#  'kaihua',
#  'tsihombe',
#  'chumikan',
#  'kaitangata',
#  'neiafu',
#  'longyearbyen',
#  'tukrah',
#  'verkhoyansk',
#  'grimshaw',
#  'temirgoyevskaya',
#  'carnarvon',
#  'korla',
#  'nicolas bravo',
#  'lagoa',
#  'zelenogorskiy',
#  'ystad',
#  'dwarka',
#  'kholmy',
#  'utiroa',
#  'takoradi',
#  'tondano',
#  'ponta delgada',
#  'palmerston',
#  'vardo',
#  'kathu',
#  'cockburn town',
#  'poum',
#  'severo-yeniseyskiy',
#  'meridian',
#  'buritama',
#  'davila',
#  'beziers',
#  'bakal',
#  'ahipara',
#  'windhoek',
#  'lockport',
#  'sulecin',
#  'henties bay',
#  'macaboboni',
#  'manokwari',
#  'port augusta',
#  'manzhouli',
#  'mehamn',
#  'vao',
#  'ribeira grande',
#  'pathein',
#  'lorengau',
#  'estelle',
#  'sungaipenuh',
#  'elat',
#  'bengkalis',
#  'quatre cocos',
#  'nguiu',
#  'buala',
#  'petropavl',
#  'barra dos coqueiros',
#  'cabedelo',
#  'kurchum',
#  'manta',
#  'kawalu',
#  'tulsipur',
#  'samusu',
#  'hargeysa',
#  'tabukiniberu',
#  'vila',
#  'marcona',
#  'norman wells',
#  'seoul',
#  'kushmurun',
#  'bembereke',
#  'kamina',
#  'vilhena',
#  'viligili',
#  'kloulklubed',
#  'san andres',
#  'chuy',
#  'general roca',
#  'lawton',
#  'jumla',
#  'baherden',
#  'la asuncion',
#  'caruray',
#  'srednekolymsk',
#  'kichha',
#  'bathsheba',
#  'kemise',
#  'bubaque',
#  'saleaula',
#  'alotau',
#  'skjervoy',
#  'bomet',
#  'kahului',
#  'cayenne',
#  'bukoba',
#  'mehtar lam',
#  'kushiro',
#  'sao joao da barra',
#  'melfi',
#  'gangotri',
#  'taoudenni',
#  'khandyga',
#  'tucuman',
#  'roald',
#  'bukachacha',
#  'san quintin',
#  'aljezur',
#  'lac du bonnet',
#  'colares',
#  'kusk',
#  'rovaniemi',
#  'mersing',
#  'ola',
#  'tilichiki',
#  'gamboula',
#  'honiara',
#  'fortuna foothills',
#  'shizunai',
#  'la tuque',
#  'geraldton',
#  'bahia honda',
#  'eyl',
#  'oltu',
#  'nizwa',
#  'port hardy',
#  'itarema',
#  'dunayivtsi',
#  'matara',
#  'yumen',
#  'mandalgovi',
#  'ler',
#  'vorukh',
#  'toliary',
#  'umm kaddadah',
#  'pinega',
#  'kalabo',
#  'labuan',
#  'wajima',
#  'labuhan',
#  'santa rosa',
#  'anzio',
#  'chiquilistlan',
#  'mount isa',
#  'salekhard',
#  'bakchar',
#  'maraa',
#  'san isidro',
#  'cape coast',
#  'hami',
#  'port macquarie',
#  'nybro',
#  'umm durman',
#  'cabo san lucas',
#  'sajoszoged',
#  'deputatskiy',
#  'katangli',
#  'ossora',
#  'basco',
#  'bykovo',
#  'meulaboh',
#  'namtsy',
#  'orzhytsya',
#  'kavaratti',
#  'helong',
#  'kincardine',
#  'cadillac',
#  'isangel',
#  'north platte',
#  'kenai',
#  'washington',
#  'ciras',
#  'zdvinsk',
#  'qafsah',
#  'sudislavl',
#  'malanje',
#  'pakxan',
#  'kakogawa',
#  'victoria falls',
#  'laguna',
#  'saint anthony',
#  'poli',
#  'bodden town',
#  'visnes',
#  'mayahi',
#  'nizhneyansk',
#  'keti bandar',
#  'inirida',
#  'chadan',
#  'shar',
#  'vanavara',
#  'tvedestrand',
#  'brake',
#  'pastavy',
#  'komsomolskiy',
#  'gold coast',
#  'samatau',
#  'aracati',
#  'inhambane',
#  'yerkoy',
#  'ust-ilimsk',
#  'atengo',
#  'merrill',
#  'zonguldak',
#  'bahia blanca',
#  'yzeure',
#  'czersk',
#  'krasnogorskoye',
#  'sola',
#  'oschersleben',
#  'kamenka',
#  'hualmay',
#  'jinchang',
#  'billings',
#  'senador jose porfirio',
#  'almaznyy',
#  'payo',
#  'buraydah',
#  'chapais',
#  'oktyabrskiy',
#  'oyama',
#  'brazzaville',
#  'murdochville',
#  'fukue',
#  'mbanza-ngungu',
#  'sal rei',
#  'genhe',
#  'port-gentil',
#  'lukino',
#  'chengmai',
#  'xianshuigu',
#  'aklavik',
#  'auki',
#  'ahuimanu',
#  'kailua',
#  'kensington',
#  'kemijarvi',
#  'xuddur',
#  'pundaguitan',
#  'kangaatsiaq',
#  'kayes',
#  'plomarion',
#  'bam',
#  'olenegorsk',
#  'ouango',
#  'half moon bay',
#  'pilar',
#  'rasulabad',
#  'togitsu',
#  'we',
#  'empangeni',
#  'socorro',
#  'waingapu',
#  'saint-denis',
#  'marsabit',
#  'diego de almagro',
#  'tateyama',
#  'balimo',
#  'uige',
#  'uyuni',
#  'karratha',
#  'grand river south east',
#  'tigil',
#  'gatesville',
#  'wiener neustadt',
#  'katsuura',
#  'hurghada',
#  'san ramon de la nueva oran',
#  'elban',
#  'cotonou',
#  'mecca',
#  'raudeberg',
#  'serov',
#  'haines junction',
#  'vitim',
#  'puerto del rosario',
#  'glazov',
#  'mizan teferi',
#  'casma',
#  'aviles',
#  'mankera',
#  'kieta',
#  'yulara',
#  'virginia beach',
#  'grand-santi',
#  'atmakur',
#  'vila franca do campo',
#  'aksarka',
#  'yenagoa',
#  'ballina',
#  'bom sucesso',
#  'coruripe',
#  'sembabule',
#  'zaterechnyy',
#  'morgan city',
#  'santa isabel do rio negro',
#  'watsa',
#  'toora-khem',
#  'ulladulla',
#  'antalaha',
#  'maceio',
#  'ostrovnoy',
#  'dharmadam',
#  'hasanpur',
#  'dutlwe',
#  'husum',
#  'wamba',
#  'minab',
#  'ylivieska',
#  'kalmunai',
#  'fougamou',
#  'maniitsoq',
#  'xiaoshi',
#  'nguruka',
#  'coahuayana',
#  'udachnyy',
#  'myitkyina',
#  'lakota',
#  'galgani',
#  'wittlich',
#  'chicama',
#  'sarkand',
#  'merke',
#  'derzhavinsk',
#  'luderitz',
#  'lasa',
#  'mendi',
#  'coihueco',
#  'san cristobal',
#  'nuevitas',
#  'franklin',
#  'ust-nera',
#  'ulcinj',
#  'bartlesville',
#  'atambua',
#  'copandaro',
#  'boyabat',
#  'darhan',
#  'sovetsk',
#  'nortelandia',
#  'fountain hills',
#  'bol',
#  'hamilton',
#  'luwero',
#  'lanzhou',
#  'hofn',
#  'sorland',
#  'maputo',
#  'alzamay',
#  'immokalee',
#  'kunda',
#  'ambanja',
#  'avera',
#  'tawkar',
#  'valparaiso',
#  'jonkoping',
#  'bandarbeyla',
#  'dengzhou',
#  'ilorin',
#  'msanga',
#  'ejido',
#  'novotroitsk',
#  'wukari',
#  'aberlour',
#  'nemuro',
#  'krasnokamensk',
#  'carutapera',
#  'kaiyuan',
#  'tumannyy',
#  'santo domingo',
#  'boyolangu',
#  'la romana',
#  'ixtapa',
#  'pinawa',
#  'khabary',
#  'zeya',
#  'progreso',
#  'honningsvag',
#  'charagua',
#  'atar',
#  'skalistyy',
#  'richards bay',
#  'ambilobe',
#  'taburi',
#  'kampene',
#  'orchard homes',
#  'quelimane',
#  'staryy nadym',
#  'kherson',
#  'chernyshevsk',
#  'karauzyak',
#  'abu kamal',
#  'hervey bay',
#  'porto santo',
#  'brunico',
#  'kuching',
#  'halifax',
#  'villanueva',
#  'puerto asis',
#  'savelugu',
#  'visby',
#  'harper',
#  'kingman',
#  'sataua',
#  'muncar',
#  'dzilam gonzalez',
#  'viedma',
#  'sabang',
#  'dzhusaly',
#  'coos bay',
#  'te anau',
#  'timizart',
#  'teguldet',
#  'tidore',
#  'kibala',
#  'panguna',
#  'baykit',
#  'tessalit',
#  'ilebo',
#  'mao',
#  'paka',
#  'chumphon',
#  'angoram',
#  'rio grande',
#  'arman',
#  'badvel',
#  'aichach',
#  'sistranda',
#  'killarney',
#  'kulu',
#  'dire',
#  'gao',
#  'burnie',
#  'vadso',
#  'homer',
#  'ukiah',
#  'abu zabad',
#  'shahrud',
#  'bolungarvik',
#  'belaya gora',
#  'male',
#  'havoysund',
#  'faya',
#  'yabrud',
#  'thyboron',
#  'macheng',
#  'camacha',
#  'sainte-marie',
#  'salvador',
#  'aripuana',
#  'kungurtug',
#  'trincomalee',
#  'gusinoye ozero',
#  'irara',
#  'arcachon',
#  'naze',
#  'pacocha',
#  'palu',
#  'bayanday',
#  'ejura',
#  'marzuq',
#  'kipini',
#  'svetlyy',
#  'calhoun',
#  'nome',
#  'peniche',
#  'shawnee',
#  'albion',
#  'orai',
#  'okulovka',
#  'cukai',
#  'san ramon',
#  'vathi',
#  'atasu',
#  'portland',
#  'selenduma']
